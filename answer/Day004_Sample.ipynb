# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"15402294252","type":"CreateEvent","actor":{"id":25116923,"login":"luthfimhmn","display_login":"luthfimhmn","gravatar_id":"","url":"https://api.github.com/users/luthfimhmn","avatar_url":"https://avatars.githubusercontent.com/u/25116923?"},"repo":{"id":344397189,"name":"Group-Portalberita/portalBeritaSains","url":"https://api.github.com/repos/Group-Portalberita/portalBeritaSains"},"payload":{"ref":"main","ref_type":"branch","master_branch":"main","description":"Repo Portal Berita Sains","pusher_type":"user"},"public":true,"created_at":"2021-03-04T08:07:36Z","org":{"id":80030735,"login":"Group-Portalberita","gravatar_id":"","url":"https://api.github.com/orgs/Group-Portalberita","avatar_url":"https://avatars.githubusercontent.com/u/80030735?"}},{"id":"15402294434","type":"DeleteEvent","actor":{"id":50578876,"login":"shtnrmt","display_login":"shtnrmt","gravatar_id":"","url":"https://api.github.com/users/shtnrmt","avatar_url":"https://avatars.githubusercontent.com/u/50578876?"},"repo":{"id":317711849,"name":"shtnrmt/MeasurementAndAnalysis_NetFramework","url":"https://api.github.com/repos/shtnrmt/MeasurementAndAnalysis_NetFramework"},"payload":{"ref":"AMIMagnetController","ref_type":"branch","pusher_type":"user"},"public":true,"created_at":"2021-03-04T08:07:37Z"},{"id":"15402294435","type":"PullRequestEvent","actor":{"id":78451071,"login":"ryota0628","display_login":"ryota0628","gravatar_id":"","url":"https://api.github.com/users/ryota0628","avatar_url":"https://avatars.githubusercontent.com/u/78451071?"},"repo":{"id":342448242,"name":"ryota0628/Laravel_caliculam","url":"https://api.github.com/repos/ryota0628/Laravel_caliculam"},"payload":{"action":"opened","number":2,"pull_request":{"url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2","id":584590992,"node_id":"MDExOlB1bGxSZXF1ZXN0NTg0NTkwOTky","html_url":"https://github.com/ryota0628/Laravel_caliculam/pull/2","diff_url":"https://github.com/ryota0628/Laravel_caliculam/pull/2.diff","patch_url":"https://github.com/ryota0628/Laravel_caliculam/pull/2.patch","issue_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2","number":2,"state":"open","locked":false,"title":"8-2 Completed","user":{"login":"ryota0628","id":78451071,"node_id":"MDQ6VXNlcjc4NDUxMDcx","avatar_url":"https://avatars.githubusercontent.com/u/78451071?v=4","gravatar_id":"","url":"https://api.github.com/users/ryota0628","html_url":"https://github.com/ryota0628","followers_url":"https://api.github.com/users/ryota0628/followers","following_url":"https://api.github.com/users/ryota0628/following{/other_user}","gists_url":"https://api.github.com/users/ryota0628/gists{/gist_id}","starred_url":"https://api.github.com/users/ryota0628/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/ryota0628/subscriptions","organizations_url":"https://api.github.com/users/ryota0628/orgs","repos_url":"https://api.github.com/users/ryota0628/repos","events_url":"https://api.github.com/users/ryota0628/events{/privacy}","received_events_url":"https://api.github.com/users/ryota0628/received_events","type":"User","site_admin":false},"body":"","created_at":"2021-03-04T08:07:37Z","updated_at":"2021-03-04T08:07:37Z","closed_at":null,"merged_at":null,"merge_commit_sha":null,"assignee":null,"assignees":[],"requested_reviewers":[],"requested_teams":[],"labels":[],"milestone":null,"draft":false,"commits_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/commits","review_comments_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/comments","review_comment_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/comments{/number}","comments_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2/comments","statuses_url":"https://api.github.com/repos/ryota0628/Laravel_caliculam/statuses/6deb094ffc8a40e6a8a5cbdf250c859a0a61e583","head":{"label":"ryota0628:dev_basis01","ref":"dev_basis01","sha":"6deb094ffc8a40e6a8a5cbdf250c859a0 ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '15402294252',
#   'type': 'CreateEvent',
#   'actor': {'id': 25116923,
#    'login': 'luthfimhmn',
#    'display_login': 'luthfimhmn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/luthfimhmn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25116923?'},
#   'repo': {'id': 344397189,
#    'name': 'Group-Portalberita/portalBeritaSains',
#    'url': 'https://api.github.com/repos/Group-Portalberita/portalBeritaSains'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Repo Portal Berita Sains',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:36Z',
#   'org': {'id': 80030735,
#    'login': 'Group-Portalberita',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Group-Portalberita',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80030735?'}},
#  {'id': '15402294434',
#   'type': 'DeleteEvent',
#   'actor': {'id': 50578876,
#    'login': 'shtnrmt',
#    'display_login': 'shtnrmt',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shtnrmt',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50578876?'},
#   'repo': {'id': 317711849,
#    'name': 'shtnrmt/MeasurementAndAnalysis_NetFramework',
#    'url': 'https://api.github.com/repos/shtnrmt/MeasurementAndAnalysis_NetFramework'},
#   'payload': {'ref': 'AMIMagnetController',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294435',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 78451071,
#    'login': 'ryota0628',
#    'display_login': 'ryota0628',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ryota0628',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?'},
#   'repo': {'id': 342448242,
#    'name': 'ryota0628/Laravel_caliculam',
#    'url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam'},
#   'payload': {'action': 'opened',
#    'number': 2,
#    'pull_request': {'url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2',
#     'id': 584590992,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTg0NTkwOTky',
#     'html_url': 'https://github.com/ryota0628/Laravel_caliculam/pull/2',
#     'diff_url': 'https://github.com/ryota0628/Laravel_caliculam/pull/2.diff',
#     'patch_url': 'https://github.com/ryota0628/Laravel_caliculam/pull/2.patch',
#     'issue_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2',
#     'number': 2,
#     'state': 'open',
#     'locked': False,
#     'title': '8-2 Completed',
#     'user': {'login': 'ryota0628',
#      'id': 78451071,
#      'node_id': 'MDQ6VXNlcjc4NDUxMDcx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ryota0628',
#      'html_url': 'https://github.com/ryota0628',
#      'followers_url': 'https://api.github.com/users/ryota0628/followers',
#      'following_url': 'https://api.github.com/users/ryota0628/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ryota0628/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ryota0628/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ryota0628/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ryota0628/orgs',
#      'repos_url': 'https://api.github.com/users/ryota0628/repos',
#      'events_url': 'https://api.github.com/users/ryota0628/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ryota0628/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2021-03-04T08:07:37Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/commits',
#     'review_comments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/comments',
#     'review_comment_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2/comments',
#     'statuses_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/statuses/6deb094ffc8a40e6a8a5cbdf250c859a0a61e583',
#     'head': {'label': 'ryota0628:dev_basis01',
#      'ref': 'dev_basis01',
#      'sha': '6deb094ffc8a40e6a8a5cbdf250c859a0a61e583',
#      'user': {'login': 'ryota0628',
#       'id': 78451071,
#       'node_id': 'MDQ6VXNlcjc4NDUxMDcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ryota0628',
#       'html_url': 'https://github.com/ryota0628',
#       'followers_url': 'https://api.github.com/users/ryota0628/followers',
#       'following_url': 'https://api.github.com/users/ryota0628/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ryota0628/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ryota0628/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ryota0628/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ryota0628/orgs',
#       'repos_url': 'https://api.github.com/users/ryota0628/repos',
#       'events_url': 'https://api.github.com/users/ryota0628/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ryota0628/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 342448242,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDI0NDgyNDI=',
#       'name': 'Laravel_caliculam',
#       'full_name': 'ryota0628/Laravel_caliculam',
#       'private': False,
#       'owner': {'login': 'ryota0628',
#        'id': 78451071,
#        'node_id': 'MDQ6VXNlcjc4NDUxMDcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ryota0628',
#        'html_url': 'https://github.com/ryota0628',
#        'followers_url': 'https://api.github.com/users/ryota0628/followers',
#        'following_url': 'https://api.github.com/users/ryota0628/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ryota0628/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ryota0628/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ryota0628/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ryota0628/orgs',
#        'repos_url': 'https://api.github.com/users/ryota0628/repos',
#        'events_url': 'https://api.github.com/users/ryota0628/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ryota0628/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ryota0628/Laravel_caliculam',
#       'description': 'カリキュラム',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam',
#       'forks_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/forks',
#       'keys_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/teams',
#       'hooks_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/events',
#       'assignees_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/tags',
#       'blobs_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/languages',
#       'stargazers_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/subscription',
#       'commits_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/merges',
#       'archive_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/downloads',
#       'issues_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/deployments',
#       'created_at': '2021-02-26T03:10:16Z',
#       'updated_at': '2021-03-01T08:42:32Z',
#       'pushed_at': '2021-03-04T08:07:37Z',
#       'git_url': 'git://github.com/ryota0628/Laravel_caliculam.git',
#       'ssh_url': 'git@github.com:ryota0628/Laravel_caliculam.git',
#       'clone_url': 'https://github.com/ryota0628/Laravel_caliculam.git',
#       'svn_url': 'https://github.com/ryota0628/Laravel_caliculam',
#       'homepage': None,
#       'size': 65,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'ryota0628:master',
#      'ref': 'master',
#      'sha': '883ba66a02d24857c36756ebbd560aaff47a8a95',
#      'user': {'login': 'ryota0628',
#       'id': 78451071,
#       'node_id': 'MDQ6VXNlcjc4NDUxMDcx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ryota0628',
#       'html_url': 'https://github.com/ryota0628',
#       'followers_url': 'https://api.github.com/users/ryota0628/followers',
#       'following_url': 'https://api.github.com/users/ryota0628/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ryota0628/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ryota0628/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ryota0628/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ryota0628/orgs',
#       'repos_url': 'https://api.github.com/users/ryota0628/repos',
#       'events_url': 'https://api.github.com/users/ryota0628/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ryota0628/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 342448242,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzNDI0NDgyNDI=',
#       'name': 'Laravel_caliculam',
#       'full_name': 'ryota0628/Laravel_caliculam',
#       'private': False,
#       'owner': {'login': 'ryota0628',
#        'id': 78451071,
#        'node_id': 'MDQ6VXNlcjc4NDUxMDcx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/78451071?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/ryota0628',
#        'html_url': 'https://github.com/ryota0628',
#        'followers_url': 'https://api.github.com/users/ryota0628/followers',
#        'following_url': 'https://api.github.com/users/ryota0628/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/ryota0628/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/ryota0628/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/ryota0628/subscriptions',
#        'organizations_url': 'https://api.github.com/users/ryota0628/orgs',
#        'repos_url': 'https://api.github.com/users/ryota0628/repos',
#        'events_url': 'https://api.github.com/users/ryota0628/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/ryota0628/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/ryota0628/Laravel_caliculam',
#       'description': 'カリキュラム',
#       'fork': False,
#       'url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam',
#       'forks_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/forks',
#       'keys_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/teams',
#       'hooks_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/hooks',
#       'issue_events_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/events',
#       'assignees_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/tags',
#       'blobs_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/languages',
#       'stargazers_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/stargazers',
#       'contributors_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/contributors',
#       'subscribers_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/subscribers',
#       'subscription_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/subscription',
#       'commits_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/merges',
#       'archive_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/downloads',
#       'issues_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/deployments',
#       'created_at': '2021-02-26T03:10:16Z',
#       'updated_at': '2021-03-01T08:42:32Z',
#       'pushed_at': '2021-03-04T08:07:37Z',
#       'git_url': 'git://github.com/ryota0628/Laravel_caliculam.git',
#       'ssh_url': 'git@github.com:ryota0628/Laravel_caliculam.git',
#       'clone_url': 'https://github.com/ryota0628/Laravel_caliculam.git',
#       'svn_url': 'https://github.com/ryota0628/Laravel_caliculam',
#       'homepage': None,
#       'size': 65,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'PHP',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2'},
#      'html': {'href': 'https://github.com/ryota0628/Laravel_caliculam/pull/2'},
#      'issue': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2'},
#      'comments': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/issues/2/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/pulls/2/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/ryota0628/Laravel_caliculam/statuses/6deb094ffc8a40e6a8a5cbdf250c859a0a61e583'}},
#     'author_association': 'OWNER',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 2,
#     'additions': 32,
#     'deletions': 105,
#     'changed_files': 5}},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294430',
#   'type': 'WatchEvent',
#   'actor': {'id': 16444334,
#    'login': 'moxuetianya',
#    'display_login': 'moxuetianya',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/moxuetianya',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16444334?'},
#   'repo': {'id': 225549581,
#    'name': 'PaddlePaddle/ElasticCTR',
#    'url': 'https://api.github.com/repos/PaddlePaddle/ElasticCTR'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 23534030,
#    'login': 'PaddlePaddle',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/PaddlePaddle',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23534030?'}},
#  {'id': '15402294429',
#   'type': 'CreateEvent',
#   'actor': {'id': 68247976,
#    'login': 'redi8',
#    'display_login': 'redi8',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/redi8',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68247976?'},
#   'repo': {'id': 344397174,
#    'name': 'redi8/YouTube-Clone',
#    'url': 'https://api.github.com/repos/redi8/YouTube-Clone'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294410',
#   'type': 'PushEvent',
#   'actor': {'id': 66110689,
#    'login': 'GabezRules',
#    'display_login': 'GabezRules',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GabezRules',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66110689?'},
#   'repo': {'id': 343215337,
#    'name': 'GabezRules/yet_another_currency_converter',
#    'url': 'https://api.github.com/repos/GabezRules/yet_another_currency_converter'},
#   'payload': {'push_id': 6641807961,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/chart_localDB',
#    'head': '24e509f38ad88e78c5a75936f097bfab227fe04b',
#    'before': '9596dcb432e4a67ce6426fd629f15663502f0d55',
#    'commits': [{'sha': '24e509f38ad88e78c5a75936f097bfab227fe04b',
#      'author': {'email': 'gabriela.zofia.zawadzka@gmail.com',
#       'name': 'GabezRules'},
#      'message': 'show all currencies in chart fragment',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GabezRules/yet_another_currency_converter/commits/24e509f38ad88e78c5a75936f097bfab227fe04b'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294213',
#   'type': 'PushEvent',
#   'actor': {'id': 29769944,
#    'login': 'rochi88',
#    'display_login': 'rochi88',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rochi88',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29769944?'},
#   'repo': {'id': 344359196,
#    'name': 'rochi88/geoflutterfireup',
#    'url': 'https://api.github.com/repos/rochi88/geoflutterfireup'},
#   'payload': {'push_id': 6641807867,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c18285154951d26bfe41eec3862c8b3c4d85b654',
#    'before': '54fabb264cfb16edf20ea7022d195c3ffcbe1304',
#    'commits': [{'sha': 'c18285154951d26bfe41eec3862c8b3c4d85b654',
#      'author': {'email': 'raisul.me@gmail.com', 'name': 'Raisul Islam'},
#      'message': 'Update pubspec.yaml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rochi88/geoflutterfireup/commits/c18285154951d26bfe41eec3862c8b3c4d85b654'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:36Z'},
#  {'id': '15402294207',
#   'type': 'WatchEvent',
#   'actor': {'id': 20431495,
#    'login': 'flystar233',
#    'display_login': 'flystar233',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/flystar233',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20431495?'},
#   'repo': {'id': 343261217,
#    'name': 'tone-row/flowchart-fun',
#    'url': 'https://api.github.com/repos/tone-row/flowchart-fun'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:36Z',
#   'org': {'id': 47831219,
#    'login': 'tone-row',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tone-row',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47831219?'}},
#  {'id': '15402294390',
#   'type': 'PushEvent',
#   'actor': {'id': 17828065,
#    'login': 'ibu1224',
#    'display_login': 'ibu1224',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ibu1224',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17828065?'},
#   'repo': {'id': 234148057,
#    'name': 'screwdriver-cd/sd-local',
#    'url': 'https://api.github.com/repos/screwdriver-cd/sd-local'},
#   'payload': {'push_id': 6641807933,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/issue-2352',
#    'head': '2610e4fea3743829645fc6c0ff3ba0edc88b54eb',
#    'before': '71c03bd7890e0ef87986cbb60d7fe04d39b5a313',
#    'commits': [{'sha': '2610e4fea3743829645fc6c0ff3ba0edc88b54eb',
#      'author': {'email': 'imiyagam@yahoo-corp.jp', 'name': 'imiyagam'},
#      'message': 'lint',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/screwdriver-cd/sd-local/commits/2610e4fea3743829645fc6c0ff3ba0edc88b54eb'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 19417863,
#    'login': 'screwdriver-cd',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/screwdriver-cd',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19417863?'}},
#  {'id': '15402294383',
#   'type': 'PushEvent',
#   'actor': {'id': 22448017,
#    'login': 'SergeyLebidko',
#    'display_login': 'SergeyLebidko',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SergeyLebidko',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22448017?'},
#   'repo': {'id': 342566023,
#    'name': 'SergeyLebidko/Abalone',
#    'url': 'https://api.github.com/repos/SergeyLebidko/Abalone'},
#   'payload': {'push_id': 6641807942,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '52e738ba09fc0bc6c919e036a97f8cc6eab87708',
#    'before': 'd98db59775bc34680d499bf55f59171f9d383ef6',
#    'commits': [{'sha': '52e738ba09fc0bc6c919e036a97f8cc6eab87708',
#      'author': {'email': 'it.sergeyler@mail.ru', 'name': 'SergeyLebidko'},
#      'message': 'Теперь корректно отображается количество заработанных очков',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/SergeyLebidko/Abalone/commits/52e738ba09fc0bc6c919e036a97f8cc6eab87708'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294393',
#   'type': 'PushEvent',
#   'actor': {'id': 16171816,
#    'login': '20chan',
#    'display_login': '20chan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/20chan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16171816?'},
#   'repo': {'id': 278588122,
#    'name': '20chan/20chan',
#    'url': 'https://api.github.com/repos/20chan/20chan'},
#   'payload': {'push_id': 6641807946,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'cb13ade3b08db030ff6bc281c2f167a293b7e107',
#    'before': '164ea43ca995b6fbfea7b672f5d6d2cf5425c792',
#    'commits': [{'sha': 'cb13ade3b08db030ff6bc281c2f167a293b7e107',
#      'author': {'email': '2+github-now@0chan.dev', 'name': 'github-now'},
#      'message': 'auto update by github-now',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/20chan/20chan/commits/cb13ade3b08db030ff6bc281c2f167a293b7e107'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294379',
#   'type': 'PushEvent',
#   'actor': {'id': 69498804,
#    'login': 'nasa1515',
#    'display_login': 'nasa1515',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/nasa1515',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69498804?'},
#   'repo': {'id': 323478576,
#    'name': 'nasa1515/nasa1515.github.io',
#    'url': 'https://api.github.com/repos/nasa1515/nasa1515.github.io'},
#   'payload': {'push_id': 6641807943,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'db96ee8c9e668f777aa6fdfd544662acef9d92da',
#    'before': '6d61ebd6a6f534863a246315a2436199d8bd3ec0',
#    'commits': [{'sha': 'db96ee8c9e668f777aa6fdfd544662acef9d92da',
#      'author': {'email': 'h43254@gmail.com', 'name': 'nasa1515'},
#      'message': 'commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/nasa1515/nasa1515.github.io/commits/db96ee8c9e668f777aa6fdfd544662acef9d92da'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294363',
#   'type': 'PushEvent',
#   'actor': {'id': 45000547,
#    'login': 'vgyyuangao',
#    'display_login': 'vgyyuangao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vgyyuangao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45000547?'},
#   'repo': {'id': 62722937,
#    'name': 'tencentyun/qcloud-documents',
#    'url': 'https://api.github.com/repos/tencentyun/qcloud-documents'},
#   'payload': {'push_id': 6641807603,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'b1c8a5eb40d136ba008bc1772ab4f0f2ed662a55',
#    'before': '64d0c581a19f65e99195b85b1c1b4b87d793e50d',
#    'commits': [{'sha': 'b1c8a5eb40d136ba008bc1772ab4f0f2ed662a55',
#      'author': {'email': '45000547+vgyyuangao@users.noreply.github.com',
#       'name': 'vgyyuangao'},
#      'message': 'Update 从公网自建MySQL迁移至云数据库MySQL.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/tencentyun/qcloud-documents/commits/b1c8a5eb40d136ba008bc1772ab4f0f2ed662a55'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 12334581,
#    'login': 'tencentyun',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/tencentyun',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12334581?'}},
#  {'id': '15402294376',
#   'type': 'PushEvent',
#   'actor': {'id': 77056318,
#    'login': 'sachinsharmaepisource',
#    'display_login': 'sachinsharmaepisource',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sachinsharmaepisource',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77056318?'},
#   'repo': {'id': 336176440,
#    'name': 'sachinsharmaepisource/documentation',
#    'url': 'https://api.github.com/repos/sachinsharmaepisource/documentation'},
#   'payload': {'push_id': 6641807938,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/check-docstring-test1.1',
#    'head': '10079ac43dde0f7c7d2aa6434ce5ecddd7733e7e',
#    'before': 'a009707cd7fd46c7b31c95b76c9859a8f5ec7249',
#    'commits': [{'sha': '10079ac43dde0f7c7d2aa6434ce5ecddd7733e7e',
#      'author': {'email': '77056318+sachinsharmaepisource@users.noreply.github.com',
#       'name': 'sachinsharmaepisource'},
#      'message': 'Update .pylintrc',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sachinsharmaepisource/documentation/commits/10079ac43dde0f7c7d2aa6434ce5ecddd7733e7e'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294399',
#   'type': 'CreateEvent',
#   'actor': {'id': 73774460,
#    'login': 'FedchenkoM',
#    'display_login': 'FedchenkoM',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/FedchenkoM',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/73774460?'},
#   'repo': {'id': 344396501,
#    'name': 'FedchenkoM/tetris',
#    'url': 'https://api.github.com/repos/FedchenkoM/tetris'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294384',
#   'type': 'DeleteEvent',
#   'actor': {'id': 29139614,
#    'login': 'renovate[bot]',
#    'display_login': 'renovate',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/renovate[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29139614?'},
#   'repo': {'id': 244322153,
#    'name': 'softwareventures/toggl-client',
#    'url': 'https://api.github.com/repos/softwareventures/toggl-client'},
#   'payload': {'ref': 'renovate/softwareventures-eslint-config-3.x',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 42502073,
#    'login': 'softwareventures',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/softwareventures',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42502073?'}},
#  {'id': '15402294367',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 9017276,
#    'login': 'mroyme',
#    'display_login': 'mroyme',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroyme',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9017276?'},
#   'repo': {'id': 11125589,
#    'name': 'keycloak/keycloak',
#    'url': 'https://api.github.com/repos/keycloak/keycloak'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/keycloak/keycloak/issues/7822',
#     'repository_url': 'https://api.github.com/repos/keycloak/keycloak',
#     'labels_url': 'https://api.github.com/repos/keycloak/keycloak/issues/7822/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/keycloak/keycloak/issues/7822/comments',
#     'events_url': 'https://api.github.com/repos/keycloak/keycloak/issues/7822/events',
#     'html_url': 'https://github.com/keycloak/keycloak/pull/7822',
#     'id': 821866800,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTg0NTgzOTMz',
#     'number': 7822,
#     'title': 'KEYCLOAK-17324 Fix javadoc for CredentialModel',
#     'user': {'login': 'mroyme',
#      'id': 9017276,
#      'node_id': 'MDQ6VXNlcjkwMTcyNzY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9017276?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mroyme',
#      'html_url': 'https://github.com/mroyme',
#      'followers_url': 'https://api.github.com/users/mroyme/followers',
#      'following_url': 'https://api.github.com/users/mroyme/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mroyme/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mroyme/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mroyme/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mroyme/orgs',
#      'repos_url': 'https://api.github.com/users/mroyme/repos',
#      'events_url': 'https://api.github.com/users/mroyme/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mroyme/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 2,
#     'created_at': '2021-03-04T07:55:29Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'closed_at': '2021-03-04T08:06:45Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/keycloak/keycloak/pulls/7822',
#      'html_url': 'https://github.com/keycloak/keycloak/pull/7822',
#      'diff_url': 'https://github.com/keycloak/keycloak/pull/7822.diff',
#      'patch_url': 'https://github.com/keycloak/keycloak/pull/7822.patch'},
#     'body': '* There are errors in the deprecation notes in the javadoc where the new methods are referred.\r\n* Some places where getCredentialData() and getSecretData() have been referred to should actually refer to getPasswordCredentialData() and getPassowordSecretData() respectively for PasswordCredentialModel.\r\n* Similarly, for OTPCredentialModel, getOTPCredentialData() anad getOTPSecretData() should be referred.\r\n\r\n<!---\r\nPlease read https://github.com/keycloak/keycloak/blob/master/CONTRIBUTING.md and follow these guidelines when contributing to Keycloak\r\n-->\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/keycloak/keycloak/issues/comments/790413172',
#     'html_url': 'https://github.com/keycloak/keycloak/pull/7822#issuecomment-790413172',
#     'issue_url': 'https://api.github.com/repos/keycloak/keycloak/issues/7822',
#     'id': 790413172,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc5MDQxMzE3Mg==',
#     'user': {'login': 'mroyme',
#      'id': 9017276,
#      'node_id': 'MDQ6VXNlcjkwMTcyNzY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/9017276?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/mroyme',
#      'html_url': 'https://github.com/mroyme',
#      'followers_url': 'https://api.github.com/users/mroyme/followers',
#      'following_url': 'https://api.github.com/users/mroyme/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/mroyme/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/mroyme/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/mroyme/subscriptions',
#      'organizations_url': 'https://api.github.com/users/mroyme/orgs',
#      'repos_url': 'https://api.github.com/users/mroyme/repos',
#      'events_url': 'https://api.github.com/users/mroyme/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/mroyme/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-03-04T08:07:37Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'author_association': 'NONE',
#     'body': "Closing as I realised that I hadn't followed some of the PR guidelines. Will raise a new one.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 4921466,
#    'login': 'keycloak',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/keycloak',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4921466?'}},
#  {'id': '15402294371',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 380403,
#    'login': 'barthalion',
#    'display_login': 'barthalion',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/barthalion',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/380403?'},
#   'repo': {'id': 88860262,
#    'name': 'flathub/flathub',
#    'url': 'https://api.github.com/repos/flathub/flathub'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/flathub/flathub/issues/2135',
#     'repository_url': 'https://api.github.com/repos/flathub/flathub',
#     'labels_url': 'https://api.github.com/repos/flathub/flathub/issues/2135/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/flathub/flathub/issues/2135/comments',
#     'events_url': 'https://api.github.com/repos/flathub/flathub/issues/2135/events',
#     'html_url': 'https://github.com/flathub/flathub/pull/2135',
#     'id': 817900441,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTgxMzEzMzUz',
#     'number': 2135,
#     'title': 'Add Matcha Azul theme (org.gtk.Gtk3theme.Matcha-azul)',
#     'user': {'login': 'Mek101',
#      'id': 34246799,
#      'node_id': 'MDQ6VXNlcjM0MjQ2Nzk5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/34246799?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Mek101',
#      'html_url': 'https://github.com/Mek101',
#      'followers_url': 'https://api.github.com/users/Mek101/followers',
#      'following_url': 'https://api.github.com/users/Mek101/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Mek101/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Mek101/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Mek101/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Mek101/orgs',
#      'repos_url': 'https://api.github.com/users/Mek101/repos',
#      'events_url': 'https://api.github.com/users/Mek101/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Mek101/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 6,
#     'created_at': '2021-02-27T11:22:36Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/flathub/flathub/pulls/2135',
#      'html_url': 'https://github.com/flathub/flathub/pull/2135',
#      'diff_url': 'https://github.com/flathub/flathub/pull/2135.diff',
#      'patch_url': 'https://github.com/flathub/flathub/pull/2135.patch'},
#     'body': '### Please confirm your submission meets all the criteria\r\n\r\n- [x] I have read the [App Requirements][reqs] and [App Maintenance][maint] pages.\r\n- [x] My pull request follows the instructions at [App Submission][submission].\r\n- [x] I am using only the minimal set of permissions. *(If not, please explain each non-standard permission.)*\r\n- [x] All assets referenced in the manifest are redistributable by any party.  If not, the unredistributable parts are using an extra-data source type.\r\n- [x] I am an upstream contributor to the project. If not, I contacted upstream developers about submitting their software to Flathub. **Link:** https://github.com/vinceliuice/Matcha-gtk-theme/issues/153\r\n- [x] I own the domain used in the application ID or the domain has a policy for delegating subdomains (e.g. GitHub, SourceForge).\r\n- [x] Any additional patches or files have been submitted to the upstream projects concerned. *(If not, explain why.)*\r\n\r\n[reqs]: https://github.com/flathub/flathub/wiki/App-Requirements\r\n[maint]: https://github.com/flathub/flathub/wiki/App-Maintenance\r\n[submission]: https://github.com/flathub/flathub/wiki/App-Submission\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/flathub/flathub/issues/comments/790413170',
#     'html_url': 'https://github.com/flathub/flathub/pull/2135#issuecomment-790413170',
#     'issue_url': 'https://api.github.com/repos/flathub/flathub/issues/2135',
#     'id': 790413170,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc5MDQxMzE3MA==',
#     'user': {'login': 'barthalion',
#      'id': 380403,
#      'node_id': 'MDQ6VXNlcjM4MDQwMw==',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/380403?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/barthalion',
#      'html_url': 'https://github.com/barthalion',
#      'followers_url': 'https://api.github.com/users/barthalion/followers',
#      'following_url': 'https://api.github.com/users/barthalion/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/barthalion/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/barthalion/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/barthalion/subscriptions',
#      'organizations_url': 'https://api.github.com/users/barthalion/orgs',
#      'repos_url': 'https://api.github.com/users/barthalion/repos',
#      'events_url': 'https://api.github.com/users/barthalion/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/barthalion/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-03-04T08:07:37Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'author_association': 'MEMBER',
#     'body': '/merge @vinceliuice',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 27268838,
#    'login': 'flathub',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/flathub',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27268838?'}},
#  {'id': '15402294360',
#   'type': 'PushEvent',
#   'actor': {'id': 1715217,
#    'login': 'taisukef',
#    'display_login': 'taisukef',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/taisukef',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1715217?'},
#   'repo': {'id': 324111088,
#    'name': 'code4sabae/opendatagojp',
#    'url': 'https://api.github.com/repos/code4sabae/opendatagojp'},
#   'payload': {'push_id': 6641807929,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '6173cf8ac7ebfc53c8ed696ecad120e548868e0b',
#    'before': '7a7353ed957f91955fb6c214e8edf550856c15a1',
#    'commits': [{'sha': '6173cf8ac7ebfc53c8ed696ecad120e548868e0b',
#      'author': {'email': 'fukuno@jig.jp', 'name': 'taisukef'},
#      'message': 'update data',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/code4sabae/opendatagojp/commits/6173cf8ac7ebfc53c8ed696ecad120e548868e0b'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 40041955,
#    'login': 'code4sabae',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/code4sabae',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40041955?'}},
#  {'id': '15402294359',
#   'type': 'PushEvent',
#   'actor': {'id': 50079005,
#    'login': 'ropensci-bot',
#    'display_login': 'ropensci-bot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ropensci-bot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50079005?'},
#   'repo': {'id': 184221415,
#    'name': 'ropensci-docs/rotl',
#    'url': 'https://api.github.com/repos/ropensci-docs/rotl'},
#   'payload': {'push_id': 6641807925,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/gh-pages',
#    'head': '87231337de0279ee511dd23d7a8835b4ea470458',
#    'before': '3a8d418b5a14602e67a10e6d6e44d6bad7e459f1',
#    'commits': [{'sha': '87231337de0279ee511dd23d7a8835b4ea470458',
#      'author': {'email': 'francois.michonneau@gmail.com',
#       'name': 'François Michonneau'},
#      'message': 'Render from https://github.com/ropensci/rotl/commit/9c13b90 (Delete .travis.yml...)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ropensci-docs/rotl/commits/87231337de0279ee511dd23d7a8835b4ea470458'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 49293403,
#    'login': 'ropensci-docs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ropensci-docs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49293403?'}},
#  {'id': '15402294357',
#   'type': 'CreateEvent',
#   'actor': {'id': 68538448,
#    'login': 'kostyamorales',
#    'display_login': 'kostyamorales',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kostyamorales',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68538448?'},
#   'repo': {'id': 344397172,
#    'name': 'kostyamorales/where_to_go',
#    'url': 'https://api.github.com/repos/kostyamorales/where_to_go'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294353',
#   'type': 'PushEvent',
#   'actor': {'id': 55138034,
#    'login': 'msh1273',
#    'display_login': 'msh1273',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/msh1273',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55138034?'},
#   'repo': {'id': 336483857,
#    'name': 'msh1273/BOJ_JAVA',
#    'url': 'https://api.github.com/repos/msh1273/BOJ_JAVA'},
#   'payload': {'push_id': 6641807934,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '60d17b799109608148084962d87324b43d5c5c7e',
#    'before': 'dda61195c5f8e543ce22ba99b0c12c9a0cb0f859',
#    'commits': [{'sha': '60d17b799109608148084962d87324b43d5c5c7e',
#      'author': {'email': '55138034+msh1273@users.noreply.github.com',
#       'name': 'Lagoon'},
#      'message': 'Update README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/msh1273/BOJ_JAVA/commits/60d17b799109608148084962d87324b43d5c5c7e'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294342',
#   'type': 'CreateEvent',
#   'actor': {'id': 71354125,
#    'login': 'aws-connector-for-github[bot]',
#    'display_login': 'aws-connector-for-github',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/aws-connector-for-github[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/71354125?'},
#   'repo': {'id': 344397190,
#    'name': 'devhub-blue-sea/org-public-empty-csc-repo-eu-west-1',
#    'url': 'https://api.github.com/repos/devhub-blue-sea/org-public-empty-csc-repo-eu-west-1'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'Empty Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 53108288,
#    'login': 'devhub-blue-sea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/devhub-blue-sea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108288?'}},
#  {'id': '15402294349',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1494693,
#    'login': 'dglo',
#    'display_login': 'dglo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dglo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1494693?'},
#   'repo': {'id': 344271281,
#    'name': 'dglo/pdaq',
#    'url': 'https://api.github.com/repos/dglo/pdaq'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/dglo/pdaq/issues/2490',
#     'repository_url': 'https://api.github.com/repos/dglo/pdaq',
#     'labels_url': 'https://api.github.com/repos/dglo/pdaq/issues/2490/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/dglo/pdaq/issues/2490/comments',
#     'events_url': 'https://api.github.com/repos/dglo/pdaq/issues/2490/events',
#     'html_url': 'https://github.com/dglo/pdaq/issues/2490',
#     'id': 821875176,
#     'node_id': 'MDU6SXNzdWU4MjE4NzUxNzY=',
#     'number': 2490,
#     'title': '[jkelley on 2015-04-09 15:25:46] : Change LBM overflow counting to differential count',
#     'user': {'login': 'dglo',
#      'id': 1494693,
#      'node_id': 'MDQ6VXNlcjE0OTQ2OTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1494693?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dglo',
#      'html_url': 'https://github.com/dglo',
#      'followers_url': 'https://api.github.com/users/dglo/followers',
#      'following_url': 'https://api.github.com/users/dglo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dglo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dglo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dglo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dglo/orgs',
#      'repos_url': 'https://api.github.com/users/dglo/repos',
#      'events_url': 'https://api.github.com/users/dglo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dglo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/dglo/pdaq/milestones/33',
#      'html_url': 'https://github.com/dglo/pdaq/milestone/33',
#      'labels_url': 'https://api.github.com/repos/dglo/pdaq/milestones/33/labels',
#      'id': 6505716,
#      'node_id': 'MDk6TWlsZXN0b25lNjUwNTcxNg==',
#      'number': 33,
#      'title': 'pDAQ:Brewery:Urban_Harvest',
#      'description': 'pDAQ:Brewery:Urban_Harvest',
#      'creator': {'login': 'dglo',
#       'id': 1494693,
#       'node_id': 'MDQ6VXNlcjE0OTQ2OTM=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1494693?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/dglo',
#       'html_url': 'https://github.com/dglo',
#       'followers_url': 'https://api.github.com/users/dglo/followers',
#       'following_url': 'https://api.github.com/users/dglo/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/dglo/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/dglo/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/dglo/subscriptions',
#       'organizations_url': 'https://api.github.com/users/dglo/orgs',
#       'repos_url': 'https://api.github.com/users/dglo/repos',
#       'events_url': 'https://api.github.com/users/dglo/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/dglo/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 1,
#      'closed_issues': 2,
#      'state': 'open',
#      'created_at': '2021-03-04T06:32:07Z',
#      'updated_at': '2021-03-04T08:07:24Z',
#      'due_on': None,
#      'closed_at': None},
#     'comments': 5,
#     'created_at': '2021-03-04T08:07:24Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'closed_at': None,
#     'author_association': 'OWNER',
#     'active_lock_reason': None,
#     'body': '\nLBM overflow counting is currently the integral count since the DOM was configured (or something similar).    This is a problem for tracking LBM overflows in SwitchRuns.  \r\n\r\nThe proposal is to change the LBM overflow count to a differential count.',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/dglo/pdaq/issues/comments/790413169',
#     'html_url': 'https://github.com/dglo/pdaq/issues/2490#issuecomment-790413169',
#     'issue_url': 'https://api.github.com/repos/dglo/pdaq/issues/2490',
#     'id': 790413169,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc5MDQxMzE2OQ==',
#     'user': {'login': 'dglo',
#      'id': 1494693,
#      'node_id': 'MDQ6VXNlcjE0OTQ2OTM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/1494693?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dglo',
#      'html_url': 'https://github.com/dglo',
#      'followers_url': 'https://api.github.com/users/dglo/followers',
#      'following_url': 'https://api.github.com/users/dglo/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dglo/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dglo/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dglo/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dglo/orgs',
#      'repos_url': 'https://api.github.com/users/dglo/repos',
#      'events_url': 'https://api.github.com/users/dglo/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dglo/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2021-03-04T08:07:37Z',
#     'updated_at': '2021-03-04T08:07:37Z',
#     'author_association': 'OWNER',
#     'body': '[dglo on 2020-04-01 12:20:14]\nUrban_Harvest is done',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294352',
#   'type': 'WatchEvent',
#   'actor': {'id': 29236082,
#    'login': 'krnithishkumar',
#    'display_login': 'krnithishkumar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/krnithishkumar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29236082?'},
#   'repo': {'id': 153097643,
#    'name': 'openvinotoolkit/openvino',
#    'url': 'https://api.github.com/repos/openvinotoolkit/openvino'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 55443902,
#    'login': 'openvinotoolkit',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/openvinotoolkit',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55443902?'}},
#  {'id': '15402294347',
#   'type': 'WatchEvent',
#   'actor': {'id': 5346577,
#    'login': 'ArturSitdikov',
#    'display_login': 'ArturSitdikov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ArturSitdikov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5346577?'},
#   'repo': {'id': 58842707,
#    'name': 'trailofbits/algo',
#    'url': 'https://api.github.com/repos/trailofbits/algo'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 2314423,
#    'login': 'trailofbits',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/trailofbits',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2314423?'}},
#  {'id': '15402294319',
#   'type': 'PushEvent',
#   'actor': {'id': 26582191,
#    'login': 'SweetOps',
#    'display_login': 'SweetOps',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/SweetOps',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26582191?'},
#   'repo': {'id': 343509571,
#    'name': 'cloudposse/terraform-aws-code-deploy',
#    'url': 'https://api.github.com/repos/cloudposse/terraform-aws-code-deploy'},
#   'payload': {'push_id': 6641807917,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '38ecf6c4f25caa94106c084aa355db87dfcd394c',
#    'before': '3efd1fbd29c3df7ba1f939c8dd0cf40c2c21686f',
#    'commits': [{'sha': '38ecf6c4f25caa94106c084aa355db87dfcd394c',
#      'author': {'email': 'vladimir.fess@gmail.com', 'name': 'Vladimir'},
#      'message': 'feat: initial implementation (#1)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cloudposse/terraform-aws-code-deploy/commits/38ecf6c4f25caa94106c084aa355db87dfcd394c'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z',
#   'org': {'id': 16398900,
#    'login': 'cloudposse',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cloudposse',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16398900?'}},
#  {'id': '15402294314',
#   'type': 'PushEvent',
#   'actor': {'id': 60847489,
#    'login': 'jyfdexh',
#    'display_login': 'jyfdexh',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jyfdexh',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60847489?'},
#   'repo': {'id': 323792733,
#    'name': 'jyfdexh/typora-imgUpload',
#    'url': 'https://api.github.com/repos/jyfdexh/typora-imgUpload'},
#   'payload': {'push_id': 6641807913,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ee14926078a05efd7f984710bad71409753b9d2b',
#    'before': '1bc5413790f1f8cbfa988008816c18ab41b6c974',
#    'commits': [{'sha': 'ee14926078a05efd7f984710bad71409753b9d2b',
#      'author': {'email': '60847489+jyfdexh@users.noreply.github.com',
#       'name': '一期一会'},
#      'message': 'Upload 2021/03/04/363204812147e577d511fa87b07395f2-image-20210304160900169-c46087.png by picGo - 2021-03-04 04:09:03',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jyfdexh/typora-imgUpload/commits/ee14926078a05efd7f984710bad71409753b9d2b'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294296',
#   'type': 'PushEvent',
#   'actor': {'id': 77938843,
#    'login': 'sunaidream',
#    'display_login': 'sunaidream',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sunaidream',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77938843?'},
#   'repo': {'id': 342811866,
#    'name': 'sunaidream/sunaidream.github.io',
#    'url': 'https://api.github.com/repos/sunaidream/sunaidream.github.io'},
#   'payload': {'push_id': 6641807907,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '12c7d5a1999238164d0d45b567e4d817f5109668',
#    'before': '1a8cbd26de831d1e8e79bd1e7c1040862b07b0a2',
#    'commits': [{'sha': '12c7d5a1999238164d0d45b567e4d817f5109668',
#      'author': {'email': '77938843+sunaidream@users.noreply.github.com',
#       'name': 'sunaidream'},
#      'message': 'message',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sunaidream/sunaidream.github.io/commits/12c7d5a1999238164d0d45b567e4d817f5109668'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'},
#  {'id': '15402294302',
#   'type': 'PushEvent',
#   'actor': {'id': 9049184,
#    'login': 'trivisonno',
#    'display_login': 'trivisonno',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trivisonno',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/9049184?'},
#   'repo': {'id': 339262149,
#    'name': 'trivisonno/ohiovaccine',
#    'url': 'https://api.github.com/repos/trivisonno/ohiovaccine'},
#   'payload': {'push_id': 6641807899,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'c347bfc5427bde9e6706c881582acce8e2be24dd',
#    'before': '01a2421f514120357ea533ab4319b7a464ef0505',
#    'commits': [{'sha': 'c347bfc5427bde9e6706c881582acce8e2be24dd',
#      'author': {'email': 'angelo@Angelos-MacBook-Air.local', 'name': 'Angelo'},
#      'message': '20210304T03:07:33',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/trivisonno/ohiovaccine/commits/c347bfc5427bde9e6706c881582acce8e2be24dd'}]},
#   'public': True,
#   'created_at': '2021-03-04T08:07:37Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60409676-1091b82c40cfa4575df6e520'},
#  'origin': '114.36.12.77',
#  'url': 'http://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60409676-329818033f441fce255324a8'},
#  'json': None,
#  'origin': '114.36.12.77',
#  'url': 'http://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.24.0',
#   'X-Amzn-Trace-Id': 'Root=1-60409677-560256f258b940d5102d2dd9'},
#  'json': None,
#  'origin': '114.36.12.77',
#  'url': 'http://httpbin.org/post'}

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
